# %%
import numpy as np
import pandas as pd

# %%
#a.	For Each .csv file create a data frame
df1=pd.read_excel('/content/Canada_Hosp2_COVID_InpatientData.xlsx')

# %%
df1.head()
# Out:
#    id reason_for_admission  age     sex ethnicity ethnicity_other  height  \
# 0   1      COVID positive    49  Female      "[]"             NaN     NaN
# 1   2  referred for sepsis   78    Male      "[]"             NaN     NaN
# 2   3                  NaN   92  Female      "[]"             NaN     NaN
# 3   4           Pneumonia    96    Male      "[]"             NaN     NaN
# 4   5       Abdominal pain   63  Female      "[]"             NaN     NaN
#
#    weight                                      comorbidities  \
# 0     NaN                                               "[]"
# 1     NaN                                               "[]"
# 2     NaN  "[\"Chronic cardiac disease (not hypertension)...
# 3     NaN  "[\"Chronic cardiac disease (not hypertension)...
# 4     NaN                                      "[\"Other\"]"
#
#                                  comorbidities_other  ... pao2 pao2_fio2  \
# 0                                                NaN  ...  NaN       NaN
# ...

# %%
df2=pd.read_excel('/content/Canada_Hosp2_COVID_InpatientData.xlsx',sheet_name='Days-breakdown')

# %%
df2.head()
# Out:
#    id  parent_id  day  systolic_blood_pressure  diastolic_blood_pressure  \
# 0   1          1    1                    118.0                      71.0
# 1   2          1    6                      NaN                       NaN
# 2   3          1    3                      NaN                       NaN
# 3   4          1    2                    129.0                      80.0
# 4   5          1    5                      NaN                       NaN
#
#    heart_rate  respiratory_rate  oxygen_saturation  temperature  \
# 0         NaN              18.0               96.0         36.0
# 1         NaN               NaN                NaN          NaN
# 2         NaN               NaN                NaN          NaN
# 3         NaN              18.0               96.0         36.0
# 4         NaN               NaN                NaN          NaN
#
#    highest_mean_arterial_pressure  ...  wall_motion_abnormality  chest_x_ray  \
# ...

# %%
df3 =pd.read_excel('/content/Canada_Hosp2_COVID_InpatientData.xlsx', sheet_name='Hospital-length-of-stay')

# %%
df3.head()
# Out:
#    id  parent_id did_the_patient_expire_in_hospital  \
# 0   1          1                                NaN
# 1   2          3                                 No
# 2   3          4                                Yes
# 3   4          5                                 No
# 4   5          6                                 No
#
#              reason_for_death  days_in_hospital_prior_to_expiration  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2  Acute Kidney Injury\nCOVID                                   6.0
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    hospital_length_of_stay  icu_length_of_stay  \
# 0                        3                 NaN
# 1                       12                 1.0
# 2                        6                 NaN
# ...

# %%
pd.DataFrame(df1)
df1
# Out:
#       id                    reason_for_admission  age     sex ethnicity  \
# 0      1                         COVID positive    49  Female      "[]"
# 1      2                     referred for sepsis   78    Male      "[]"
# 2      3                                     NaN   92  Female      "[]"
# 3      4                              Pneumonia    96    Male      "[]"
# 4      5                          Abdominal pain   63  Female      "[]"
# ..   ...                                     ...  ...     ...       ...
# 196  197                       COVID-19 Positive   32  Female      "[]"
# 197  198            COVID-19 Positive, Pneumonia   65    Male      "[]"
# 198  199                       COVID-19 Positive   60    Male      "[]"
# 199  200  COVID-19 positive, Struck by vehicle     63    Male      "[]"
# 200  201                     COVID-19 Pneumonia    81  Female      "[]"
#
#     ethnicity_other  height  weight  \
# 0               NaN     NaN     NaN
# ...

# %%
pd.DataFrame(df2)
df2
# Out:
#         id  parent_id  day  systolic_blood_pressure  diastolic_blood_pressure  \
# 0        1          1    1                    118.0                      71.0
# 1        2          1    6                      NaN                       NaN
# 2        3          1    3                      NaN                       NaN
# 3        4          1    2                    129.0                      80.0
# 4        5          1    5                      NaN                       NaN
# ...    ...        ...  ...                      ...                       ...
# 1569  1570        201    4                      NaN                       NaN
# 1570  1571        201    5                      NaN                       NaN
# 1571  1572        201    6                    125.0                      45.0
# 1572  1573        201    7                    149.0                      59.0
# 1573  1574        201   14                    122.0                      64.0
#
# ...

# %%
pd.DataFrame(df3)
df3
# Out:
#       id  parent_id did_the_patient_expire_in_hospital  \
# 0      1          1                                NaN
# 1      2          3                                 No
# 2      3          4                                Yes
# 3      4          5                                 No
# 4      5          6                                 No
# ..   ...        ...                                ...
# 194  195        197                                 No
# 195  196        198                                 No
# 196  197        199                                 No
# 197  198        200                                 No
# 198  199        201                                 No
#
#                reason_for_death  days_in_hospital_prior_to_expiration  \
# 0                           NaN                                   NaN
# 1                           NaN                                   NaN
# 2    Acute Kidney Injury\nCOVID                                   6.0
# ...

# %%
#b.	Merge all data frames one data frame ( don’t merge all columns select valuable based on your opinion Min=20 Att )

frames = [df1, df2, df3]
newdf = df1.merge(df2, how='right')
print(newdf)
# Out:
#         id reason_for_admission  age  sex ethnicity ethnicity_other  height  \
# 0        1                  NaN  NaN  NaN       NaN             NaN     NaN
# 1        2                  NaN  NaN  NaN       NaN             NaN     NaN
# 2        3                  NaN  NaN  NaN       NaN             NaN     NaN
# 3        4                  NaN  NaN  NaN       NaN             NaN     NaN
# 4        5                  NaN  NaN  NaN       NaN             NaN     NaN
# ...    ...                  ...  ...  ...       ...             ...     ...
# 1569  1570                  NaN  NaN  NaN       NaN             NaN     NaN
# 1570  1571                  NaN  NaN  NaN       NaN             NaN     NaN
# 1571  1572                  NaN  NaN  NaN       NaN             NaN     NaN
# 1572  1573                  NaN  NaN  NaN       NaN             NaN     NaN
# 1573  1574                  NaN  NaN  NaN       NaN             NaN     NaN
#
# ...

# %%
#2
frames=[df1.iloc[:,0:20],df2.iloc[:,0:20],df3.iloc[:,0:20]]
result=pd.concat(frames)
#to print resultp
print(result)
# Out:
#       id reason_for_admission   age     sex ethnicity ethnicity_other  height  \
# 0      1      COVID positive   49.0  Female      "[]"             NaN     NaN
# 1      2  referred for sepsis  78.0    Male      "[]"             NaN     NaN
# 2      3                  NaN  92.0  Female      "[]"             NaN     NaN
# 3      4           Pneumonia   96.0    Male      "[]"             NaN     NaN
# 4      5       Abdominal pain  63.0  Female      "[]"             NaN     NaN
# ..   ...                  ...   ...     ...       ...             ...     ...
# 194  195                  NaN   NaN     NaN       NaN             NaN     NaN
# 195  196                  NaN   NaN     NaN       NaN             NaN     NaN
# 196  197                  NaN   NaN     NaN       NaN             NaN     NaN
# 197  198                  NaN   NaN     NaN       NaN             NaN     NaN
# 198  199                  NaN   NaN     NaN       NaN             NaN     NaN
#
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1974 entries, 0 to 198
# Data columns (total 45 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id                                                1974 non-null   int64
#  1   reason_for_admission                              199 non-null    object
#  2   age                                               201 non-null    float64
#  3   sex                                               198 non-null    object
#  4   ethnicity                                         201 non-null    object
#  5   ethnicity_other                                   58 non-null     object
#  6   height                                            25 non-null     float64
#  7   weight                                            31 non-null     float64
#  8   comorbidities                                     201 non-null    object
# ...

# %%
# c.	Display number of Nulls or Missing Values in Each Column
df1.isnull().sum()
# Out:
# id                                    0
# reason_for_admission                  2
# age                                   0
# sex                                   3
# ethnicity                             0
# ethnicity_other                     143
# height                              176
# weight                              170
# comorbidities                         0
# comorbidities_other                  84
# received_covid_vaccine               14
# covid_vaccine                       200
# medications                           0
# smoking_history                       8
# year_they_quit                      182
# previous_er_visit_within_14_days      8
# admission_disposition                 8
# systolic_blood_pressure               8
# diastolic_blood_pressure              9
# heart_rate                           27
# respiratory_rate                     23
# oxygen_saturation                    11
# temperature                          14
# ...

# %%
df2.isnull().sum()
# Out:
# id                            0
# parent_id                     0
# day                           0
# systolic_blood_pressure     494
# diastolic_blood_pressure    494
#                            ...
# head_ct                     461
# head_ct_findings              0
# antimicrobial               437
# anticoagulation             433
# steroid                     440
# Length: 70, dtype: int64

# %%
df3.isnull().sum()
# Out:
# id                                                    0
# parent_id                                             0
# did_the_patient_expire_in_hospital                    6
# reason_for_death                                    170
# days_in_hospital_prior_to_expiration                170
# hospital_length_of_stay                               0
# icu_length_of_stay                                  144
# days_in_hospital_prior_to_icu_admission             180
# time_on_mechanical_ventilation                      165
# days_in_hospital_prior_to_mechanical_ventilation    178
# days_to_first_covid19_test_negative                 181
# dtype: int64

# %%
df1.notnull().sum()
# Out:
# id                                  201
# reason_for_admission                199
# age                                 201
# sex                                 198
# ethnicity                           201
# ethnicity_other                      58
# height                               25
# weight                               31
# comorbidities                       201
# comorbidities_other                 117
# received_covid_vaccine              187
# covid_vaccine                         1
# medications                         201
# smoking_history                     193
# year_they_quit                       19
# previous_er_visit_within_14_days    193
# admission_disposition               193
# systolic_blood_pressure             193
# diastolic_blood_pressure            192
# heart_rate                          174
# respiratory_rate                    178
# oxygen_saturation                   190
# temperature                         187
# ...

# %%
df2.notnull().sum()
# Out:
# id                          1574
# parent_id                   1574
# day                         1574
# systolic_blood_pressure     1080
# diastolic_blood_pressure    1080
#                             ...
# head_ct                     1113
# head_ct_findings            1574
# antimicrobial               1137
# anticoagulation             1141
# steroid                     1134
# Length: 70, dtype: int64

# %%
df3.notnull().sum()
# Out:
# id                                                  199
# parent_id                                           199
# did_the_patient_expire_in_hospital                  193
# reason_for_death                                     29
# days_in_hospital_prior_to_expiration                 29
# hospital_length_of_stay                             199
# icu_length_of_stay                                   55
# days_in_hospital_prior_to_icu_admission              19
# time_on_mechanical_ventilation                       34
# days_in_hospital_prior_to_mechanical_ventilation     21
# days_to_first_covid19_test_negative                  18
# dtype: int64

# %%
df1.fillna(value='FILL VALUE')
# Out:
#       id                    reason_for_admission  age     sex ethnicity  \
# 0      1                         COVID positive    49  Female      "[]"
# 1      2                     referred for sepsis   78    Male      "[]"
# 2      3                              FILL VALUE   92  Female      "[]"
# 3      4                              Pneumonia    96    Male      "[]"
# 4      5                          Abdominal pain   63  Female      "[]"
# ..   ...                                     ...  ...     ...       ...
# 196  197                       COVID-19 Positive   32  Female      "[]"
# 197  198            COVID-19 Positive, Pneumonia   65    Male      "[]"
# 198  199                       COVID-19 Positive   60    Male      "[]"
# 199  200  COVID-19 positive, Struck by vehicle     63    Male      "[]"
# 200  201                     COVID-19 Pneumonia    81  Female      "[]"
#
#     ethnicity_other      height      weight  \
# 0        FILL VALUE  FILL VALUE  FILL VALUE
# ...

# %%
#d.	IF Numeric Handle Missing Value ( AVG, MAX, MIN)

from numpy.lib.function_base import average
average(result.isnull().sum())
# Out:
# 1576.8

# %%
max(result.isnull().sum())
# Out:
# 1973

# %%
min(result.isnull().sum())
# Out:
# 0

# %%
#e.	Save this data frame to another CSV called (DS_Prepared)
result.to_csv('DS_Prepared.csv',index = False)
DataFramePrepared = pd.read_csv('DS_Prepared.csv')

# %%
DataFramePrepared.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 45 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id                                                1974 non-null   int64
#  1   reason_for_admission                              199 non-null    object
#  2   age                                               201 non-null    float64
#  3   sex                                               198 non-null    object
#  4   ethnicity                                         201 non-null    object
#  5   ethnicity_other                                   58 non-null     object
#  6   height                                            25 non-null     float64
#  7   weight                                            31 non-null     float64
#  8   comorbidities                                     201 non-null    object
# ...

# %%
#f.	Based on your data construct at least 3 more attributes and add them to your data set ( add , subtract , multiply, concatenate)
add =DataFramePrepared["height"]+ DataFramePrepared["weight"]
DataFramePrepared["Sum"] = add
print(DataFramePrepared)
#DataFramePrepared.head(50)
# Out:
#        id reason_for_admission   age     sex ethnicity ethnicity_other  \
# 0       1      COVID positive   49.0  Female      "[]"             NaN
# 1       2  referred for sepsis  78.0    Male      "[]"             NaN
# 2       3                  NaN  92.0  Female      "[]"             NaN
# 3       4           Pneumonia   96.0    Male      "[]"             NaN
# 4       5       Abdominal pain  63.0  Female      "[]"             NaN
# ...   ...                  ...   ...     ...       ...             ...
# 1969  195                  NaN   NaN     NaN       NaN             NaN
# 1970  196                  NaN   NaN     NaN       NaN             NaN
# 1971  197                  NaN   NaN     NaN       NaN             NaN
# 1972  198                  NaN   NaN     NaN       NaN             NaN
# 1973  199                  NaN   NaN     NaN       NaN             NaN
#
#       height  weight                                      comorbidities  \
# ...

# %%
sub_column = DataFramePrepared["systolic_blood_pressure"] - DataFramePrepared["diastolic_blood_pressure"]
DataFramePrepared["systolic-diastolic"] = sub_column
print(DataFramePrepared)
# Out:
#        id reason_for_admission   age     sex ethnicity ethnicity_other  \
# 0       1      COVID positive   49.0  Female      "[]"             NaN
# 1       2  referred for sepsis  78.0    Male      "[]"             NaN
# 2       3                  NaN  92.0  Female      "[]"             NaN
# 3       4           Pneumonia   96.0    Male      "[]"             NaN
# 4       5       Abdominal pain  63.0  Female      "[]"             NaN
# ...   ...                  ...   ...     ...       ...             ...
# 1969  195                  NaN   NaN     NaN       NaN             NaN
# 1970  196                  NaN   NaN     NaN       NaN             NaN
# 1971  197                  NaN   NaN     NaN       NaN             NaN
# 1972  198                  NaN   NaN     NaN       NaN             NaN
# 1973  199                  NaN   NaN     NaN       NaN             NaN
#
#       height  weight                                      comorbidities  \
# ...

# %%
mul = DataFramePrepared["systolic_blood_pressure"] * DataFramePrepared["diastolic_blood_pressure"]
DataFramePrepared["systolic*diastolic"] = mul
print(DataFramePrepared)
# Out:
#        id reason_for_admission   age     sex ethnicity ethnicity_other  \
# 0       1      COVID positive   49.0  Female      "[]"             NaN
# 1       2  referred for sepsis  78.0    Male      "[]"             NaN
# 2       3                  NaN  92.0  Female      "[]"             NaN
# 3       4           Pneumonia   96.0    Male      "[]"             NaN
# 4       5       Abdominal pain  63.0  Female      "[]"             NaN
# ...   ...                  ...   ...     ...       ...             ...
# 1969  195                  NaN   NaN     NaN       NaN             NaN
# 1970  196                  NaN   NaN     NaN       NaN             NaN
# 1971  197                  NaN   NaN     NaN       NaN             NaN
# 1972  198                  NaN   NaN     NaN       NaN             NaN
# 1973  199                  NaN   NaN     NaN       NaN             NaN
#
#       height  weight                                      comorbidities  \
# ...

# %%
Statcolumn = DataFramePrepared['reason_for_admission'] +"-"+ DataFramePrepared["age"].astype(str)
DataFramePrepared["age/reason"]=Statcolumn 
print(DataFramePrepared)
# Out:
#        id reason_for_admission   age     sex ethnicity ethnicity_other  \
# 0       1      COVID positive   49.0  Female      "[]"             NaN
# 1       2  referred for sepsis  78.0    Male      "[]"             NaN
# 2       3                  NaN  92.0  Female      "[]"             NaN
# 3       4           Pneumonia   96.0    Male      "[]"             NaN
# 4       5       Abdominal pain  63.0  Female      "[]"             NaN
# ...   ...                  ...   ...     ...       ...             ...
# 1969  195                  NaN   NaN     NaN       NaN             NaN
# 1970  196                  NaN   NaN     NaN       NaN             NaN
# 1971  197                  NaN   NaN     NaN       NaN             NaN
# 1972  198                  NaN   NaN     NaN       NaN             NaN
# 1973  199                  NaN   NaN     NaN       NaN             NaN
#
#       height  weight                                      comorbidities  \
# ...

# %%
#Part2
#i.	USING PRINT Display Number of Rows 
count_rows =len(DataFramePrepared.index)
print(count_rows)
# Out:
# 1974

# %%
#ii.	USING PRINT Display Column Names and  Number of Columns
DataFramePrepared.head()
print(DataFramePrepared.columns)
count_columns =len(DataFramePrepared.index)
print(count_columns)
# Out:
# Index(['id', 'reason_for_admission', 'age', 'sex', 'ethnicity',
#        'ethnicity_other', 'height', 'weight', 'comorbidities',
#        'comorbidities_other', 'received_covid_vaccine', 'covid_vaccine',
#        'medications', 'smoking_history', 'year_they_quit',
#        'previous_er_visit_within_14_days', 'admission_disposition',
#        'systolic_blood_pressure', 'diastolic_blood_pressure', 'heart_rate',
#        'parent_id', 'day', 'respiratory_rate', 'oxygen_saturation',
#        'temperature', 'highest_mean_arterial_pressure',
#        'lowest_mean_arterial_pressure', 'highest_heart_rate',
#        'lowest_heart_rate', 'highest_creatinine', 'lowest_urine_output',
#        'highest_gcs', 'lowest_gcs', 'intubated', 'highest_ph', 'lowest_ph',
#        'did_the_patient_expire_in_hospital', 'reason_for_death',
#        'days_in_hospital_prior_to_expiration', 'hospital_length_of_stay',
#        'icu_length_of_stay', 'days_in_hospital_prior_to_icu_admission',
# ...

# %%
#iii.	USING PRINT Display Data Frame Size
ds=DataFramePrepared.size
print(ds)
# Out:
# 92778

# %%
dsh=DataFramePrepared.shape
print(dsh)
# Out:
# (1974, 49)

# %%
#iv.	USING PRINT Display Data Frame First Little Records( Display all columns )
result= DataFramePrepared.head(10)
print("First 10 rows of dataframe : ")
print(result)
# Out:
# First 10 rows of dataframe :
#    id                               reason_for_admission   age     sex  \
# 0   1                                    COVID positive   49.0  Female
# 1   2                                referred for sepsis  78.0    Male
# 2   3                                                NaN  92.0  Female
# 3   4                                         Pneumonia   96.0    Male
# 4   5                                     Abdominal pain  63.0  Female
# 5   6                                           COVID-19  88.0    Male
# 6   7                                              COVID  89.0  Female
# 7   8  renal failure complicated by uremic encephalop...  68.0    Male
# 8   9                                    COVID pneumonia  66.0  Female
# 9  10  OVID positive today transferred for further ma...  80.0  Female
#
#        ethnicity ethnicity_other  height  weight  \
# 0           "[]"             NaN     NaN     NaN
# 1           "[]"             NaN     NaN     NaN
# ...

# %%
#v.	USING PRINT Display Data Frame First Little Records 
FirstR =DataFramePrepared.iloc[:10,:10]
print(FirstR)
# Out:
#    id                               reason_for_admission   age     sex  \
# 0   1                                    COVID positive   49.0  Female
# 1   2                                referred for sepsis  78.0    Male
# 2   3                                                NaN  92.0  Female
# 3   4                                         Pneumonia   96.0    Male
# 4   5                                     Abdominal pain  63.0  Female
# 5   6                                           COVID-19  88.0    Male
# 6   7                                              COVID  89.0  Female
# 7   8  renal failure complicated by uremic encephalop...  68.0    Male
# 8   9                                    COVID pneumonia  66.0  Female
# 9  10  OVID positive today transferred for further ma...  80.0  Female
#
#        ethnicity ethnicity_other  height  weight  \
# 0           "[]"             NaN     NaN     NaN
# 1           "[]"             NaN     NaN     NaN
# ...

# %%
x=DataFramePrepared.head(10)
print("First 10 record of the dataFrame: ")
print(x)
# Out:
# First 10 record of the dataFrame:
#    id                               reason_for_admission   age     sex  \
# 0   1                                    COVID positive   49.0  Female
# 1   2                                referred for sepsis  78.0    Male
# 2   3                                                NaN  92.0  Female
# 3   4                                         Pneumonia   96.0    Male
# 4   5                                     Abdominal pain  63.0  Female
# 5   6                                           COVID-19  88.0    Male
# 6   7                                              COVID  89.0  Female
# 7   8  renal failure complicated by uremic encephalop...  68.0    Male
# 8   9                                    COVID pneumonia  66.0  Female
# 9  10  OVID positive today transferred for further ma...  80.0  Female
#
#        ethnicity ethnicity_other  height  weight  \
# 0           "[]"             NaN     NaN     NaN
# 1           "[]"             NaN     NaN     NaN
# ...

# %%
#vi.	USING PRINT Display Data Frame NUMBER OF ELEMENTS
DataFramePrepared.size
# Out:
# 96726

# %%
df2.size
# Out:
# 110180

# %%
df3.size
# Out:
# 2189

# %%
#viii.	Select at least 2 numeric attribute and try to analyze its data 
#Min
DataFramePrepared[[ "systolic_blood_pressure","diastolic_blood_pressure"]].min()
# Out:
# systolic_blood_pressure     74.0
# diastolic_blood_pressure    36.0
# dtype: float64

# %%
#Max
DataFramePrepared[[ "systolic_blood_pressure","diastolic_blood_pressure"]].max()
# Out:
# systolic_blood_pressure     230.0
# diastolic_blood_pressure    194.0
# dtype: float64

# %%
#3.	AVG Value 
DataFramePrepared[[ "systolic_blood_pressure","diastolic_blood_pressure"]].mean()
# Out:
# systolic_blood_pressure     127.798115
# diastolic_blood_pressure     71.474843
# dtype: float64

# %%
#xi.	For Column AGE display a summary statistics that describes this column
DataFramePrepared["age"].describe()
# Out:
# count    201.000000
# mean      67.054726
# std       19.667536
# min       18.000000
# 25%       56.000000
# 50%       69.000000
# 75%       83.000000
# max       98.000000
# Name: age, dtype: float64

# %%
#xii.	Group Your Data By ‘SEX’ Column then Display the mean values of other Columns 
df1_groupby_sex = df1.groupby('sex')
df1_groupby_sex.mean()
# Out:
#                 id       age      height     weight  year_they_quit  \
# sex
# Female   98.122449  68.22449  161.727273  76.415385     1999.250000
# Male    104.830000  65.87000  171.428571  79.638889     2000.714286
#
#         systolic_blood_pressure  diastolic_blood_pressure  heart_rate  \
# sex
# Female               130.840426                 73.553191   91.423529
# Male                 133.635417                 75.705263   89.941860
#
#         respiratory_rate  oxygen_saturation  ...  pao2  pao2_fio2        ph  \
# sex                                          ...
# Female         21.056818          93.527473  ...  84.0        NaN  7.314390
# Male           21.195402          93.312500  ...  74.0        NaN  7.376977
#
#         high_senstivity_cardiac_troponin   esr       inr    ferritin  \
# sex
# Female                              35.5   NaN  1.284634  361.083333
# Male                                30.5  26.5  1.357609  879.454545
#
# ...

# %%
# xiii.	Determine How many rows are F or M
df1_groupby_sex.size()
# Out:
# sex
# Female     98
# Male      100
# dtype: int64

# %%
	# CONVERT YOUR .CSV TO .TXT FILE

# !pip install jpype1
# !pip install aspose-cells
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 453 kB 41.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.2 MB 17.6 MB/s
# ...
#   Created wheel for aspose-cells: filename=aspose_cells-22.5.0-py3-none-any.whl size=12133312 sha256=015204e41e2c03f2a19572b6c2279a14bbb3174474df1322deed8696ce18db36
#   Stored in directory: /root/.cache/pip/wheels/d0/c5/c4/0c4828463a300ba53fbf959fdd9ae868e4aec9cafc9bd4c79d
# Successfully built aspose-cells
# ...

# %%
import jpype
import asposecells     
#jpype.startJVM() 
from asposecells.api import Workbook
workbook = Workbook("DS_Prepared.csv");
workbook.save("Output.txt");
jpype.shutdownJVM()

# %%
file = open('Output.txt', 'r')
read_data = file.read()
read_word = read_data.split()
print('Total Words:', len(read_word))
# Out:
# Total Words: 20093

# %%
import nltk

with open ("Output.txt", "r") as myfile:
    data=myfile.read().replace('\n', ' ')

data = data.split(' ')
fdist1 = nltk.FreqDist(data)
print (fdist1.most_common(50))
# Out:
# [('Select', 149), ('an', 149), ('TAB', 51), ('disease', 40), ('cardiac', 39), ('(not', 39), ('of', 38), ('Positive', 37), ('', 29), ('pulmonary', 26), ('(lung)', 26), ('[any', 23), ('in', 22), ('D', 20), ('neurological', 19), ('and', 19), ('cancer', 19), ('[now', 19), ('disorder,', 18), ('pneumonia', 11), ('REGULAR', 11), ('hypertension)\\"",\\""Chronic', 10), ('GERD,', 10), ('hypertension)\\"",\\""Hypertension\\"",\\""Chronic', 9), ('INHALER', 9), ('disorder\\"",\\""Dementia', 9), ('pack', 9), ('disease\\"",\\""Chronic', 8), ('by', 8), ('Pneumonia', 8), ('30', 7), ('Bipolar', 7), ('\\"",\\""dosage\\"":\\""\\"",\\""frequency\\"":\\""Please', 7), ('\tNo\t\t"""[{\\""medications\\"":\\""\\"",\\""dosage\\"":\\""\\"",\\""frequency\\"":\\""Please', 7), ('positive', 6), ('UNIT\\"",\\""dosage\\"":\\""1000', 6), ('depressive', 6), ('Generalized', 6), ('anxiety', 6), ('(Complex)', 6), ('PTSD', 6), ('history,', 6), ('R/O', 6), ('disorder', 6), ('COVID-19', 6), ('disease\\"",\\""History', 6), ('
# ...

# %%
#Part3 a.	Using Box Plot

import matplotlib.pyplot as plt
DataFramePrepared[['age','systolic_blood_pressure']].plot.box()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#b.	Using SCATTER Plot
DataFramePrepared = pd.read_csv('DS_Prepared.csv')
plt.scatter( x = DataFramePrepared['age'], y = DataFramePrepared['diastolic_blood_pressure'], c ="red")
plt.show()

# %%
# USING BAR PLOT
DataFramePrepared = pd.read_csv('DS_Prepared.csv')
plt.bar(DataFramePrepared['age'],DataFramePrepared['diastolic_blood_pressure'], color ='maroon'
        )
 
plt.xlabel("age")
plt.ylabel("blood pressure")
plt.title("bar plot")
plt.show()

# %%
#	Using Histogram
DataFramePrepared['age'].plot.hist()

# %%
#f.	Using HeatMap
import seaborn as sns
sns.heatmap(df3.corr(),cmap='coolwarm',annot=True)

# %%
#i.	TRY TO DISCIBE YOUR DATA
